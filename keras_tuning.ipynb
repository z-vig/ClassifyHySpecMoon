# %% [markdown]
# # AOSC650 Term Project
# ###### In this project, I will be attempting to classify different types of lunar mineralogies based on hyperspectral data from the Moon Mineralogy Mapper (M3). This will be done using a simple Multilayer Perceptron Model.

# %%
#Local Imports
from classifyhyspecmoon.neuralnetdata import NeuralNetData
from classifyhyspecmoon.buildNN import run_mlp,MyHyperParameters,tune_model

#Remote Imports
import matplotlib.pyplot as plt
from matplotlib import ticker
import matplotlib.font_manager as fnt_mang
import numpy as np
from matplotlib.colors import ListedColormap
# Out:
# Thank you for using ClassifyHySpecMoon by z-vig!
# WARNING:tensorflow:From c:\Users\zvig\Desktop\python_code\ClassifyHySpecMoon\.venv\Lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.

# %%
#Getting Raw Spectral Data and placing it in mydata ojbect.
mydata = NeuralNetData('C:/Users/zvig/.julia/dev/JENVI.jl/Data/targeted.hdf5')
print(f'Loaded in data of shape: {mydata.smoothspec.shape}')
print(f'Reminder: (bands,ydimension,xdimension)')
plt.imshow(mydata.smoothspec[200,:,:],cmap='gray')
plt.xticks([]); plt.yticks([])
plt.savefig('G:/My Drive/Machine Learning Project/Figures/m3_image.png',dpi=800)
# Out:
# Loaded in data of shape: (239, 584, 408)
# Reminder: (bands,ydimension,xdimension)

# %% [markdown]
# #### Label Creation for Supervised Learning

# %%
#Creating data labels based on the Spectral ANgle Mapper (SAM) technique.

# Defining reference spectra for labeling.
olpt = (200,284)
refspec1 = mydata.smoothspec[:,*olpt] #olivine
olcheck = mydata.contrem[:,*olpt]
refspec2 = mydata.smoothspec[:,500,200] #mare (South)
refspec3 = mydata.smoothspec[:,190,360] #mare (North)
refspec4 = mydata.smoothspec[:,300,200] #dome center
refspec5 = mydata.smoothspec[:,320,100] #dome flank
refspec_raw = mydata.rawspec[:,200,280]
refspec_dict = {'Olivine':(refspec1,1.2),'Mare1':(refspec2,1),'Mare2':(refspec3,0.7),'Dome1':(refspec4,1),'Dome2':(refspec5,1)} #Dictionary of tuples {str:(array,threshold)}

#Labeling data by modifying mydata object
mydata.label_data('Spectral_Angle',refspec_dict)
# Out:
# c:\Users\zvig\Desktop\python_code\ClassifyHySpecMoon\classifyhyspecmoon\create_labels.py:23: RuntimeWarning: invalid value encountered in arccos
#   spa = 180*np.arccos(np.einsum('ijk,ijk->ij',M,I)/(np.linalg.norm(M,axis=2)*np.linalg.norm(I,axis=2)))/np.pi

# %%
mydata.onehot_encoding()

# %%
import keras_tuner
tuner = keras_tuner.RandomSearch(
    hypermodel=tune_model,
    objective='val_loss',
    max_trials=5,
    overwrite=True,
    project_name='aosc_project'
)
#summarizing search space
tuner.search_space_summary()
# Out:
# WARNING:tensorflow:From c:\Users\zvig\Desktop\python_code\ClassifyHySpecMoon\.venv\Lib\site-packages\keras\src\backend.py:873: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# WARNING:tensorflow:From c:\Users\zvig\Desktop\python_code\ClassifyHySpecMoon\.venv\Lib\site-packages\keras\src\backend.py:6642: The name tf.nn.max_pool is deprecated. Please use tf.nn.max_pool2d instead.
#
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d (Conv1D)             (None, 239, 10)           310
#
#  max_pooling1d (MaxPooling1  (None, 119, 10)           0
#  D)
#
#  conv1d_1 (Conv1D)           (None, 105, 10)           1510
#
#  max_pooling1d_1 (MaxPoolin  (None, 52, 10)            0
#  g1D)
#
#  flatten (Flatten)           (None, 520)               0
#
#  dense (Dense)               (None, 10)                5210
#
#  dense_1 (Dense)             (None, 10)                110
#
#  dense_2 (Dense)             (None, 7)                 77
#
# =================================================================
# Total params: 7217 (28.19 KB)
# Trainable params: 7217 (28.19 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# None
# Search space summary
# Default search space size: 7
# n_layers (Int)
# {'default': 2, 'conditions': [], 'min_value': 1, 'max_value': 4, 'step': 1, 'sampling': 'linear'}
# units_0 (Int)
# {'default': None, 'conditions': [], 'min_value': 10, 'max_value': 200, 'step': 10, 'sampling': 'linear'}
# units_1 (Int)
# {'default': None, 'conditions': [], 'min_value': 10, 'max_value': 200, 'step': 10, 'sampling': 'linear'}
# activation_0 (Choice)
# {'default': 'relu', 'conditions': [], 'values': ['relu', 'tanh'], 'ordered': False}
# activation_1 (Choice)
# {'default': 'relu', 'conditions': [], 'values': ['relu', 'tanh'], 'ordered': False}
# learning_rate (Float)
# {'default': 0.001, 'conditions': [], 'min_value': 0.001, 'max_value': 10.0, 'step': 10, 'sampling': 'log'}
# batch_size (Int)
# {'default': None, 'conditions': [], 'min_value': 500, 'max_value': 1500, 'step': 100, 'sampling': 'linear'}

# %%
mydata.split_train_test()
mydata.minmax_normalization((0,1))
print(mydata.X_train.shape)
# Out:
# (178704, 239)

# %%
from sklearn.utils.class_weight import compute_class_weight

train_decoded = np.argmax(mydata.Y_train,axis=1)
class_weight_dict = dict(enumerate(compute_class_weight('balanced',
                                        classes=np.unique(train_decoded),
                                        y=train_decoded)))
mydata.get_validation_data()

tuner.search(mydata.X_train_noval,mydata.Y_train_noval,
             epochs=2,
             validation_data=(mydata.X_val,mydata.Y_val),
             class_weight = class_weight_dict
             )
tuner.results_summary()
# Out:
# Trial 5 Complete [00h 00m 27s]
# val_loss: 0.40280306339263916
#
# Best val_loss So Far: 0.1775406450033188
# Total elapsed time: 00h 02m 04s
# Results summary
# Results in .\aosc_project
# Showing 10 best trials
# Objective(name="val_loss", direction="min")
#
# Trial 3 summary
# Hyperparameters:
# n_layers: 2
# units_0: 90
# units_1: 150
# activation_0: tanh
# activation_1: tanh
# learning_rate: 0.1
# batch_size: 1100
# units_2: 90
# activation_2: tanh
# Score: 0.1775406450033188
#
# Trial 2 summary
# Hyperparameters:
# n_layers: 2
# units_0: 20
# units_1: 20
# activation_0: tanh
# activation_1: tanh
# learning_rate: 0.01
# batch_size: 1500
# units_2: 110
# activation_2: relu
# Score: 0.36273542046546936
#
# Trial 4 summary
# Hyperparameters:
# n_layers: 4
# units_0: 40
# units_1: 70
# activation_0: relu
# activation_1: relu
# learning_rate: 0.001
# batch_size: 1300
# units_2: 170
# activation_2: relu
# units_3: 10
# activation_3: relu
# Score: 0.40280306339263916
#
# Trial 1 summary
# Hyperparameters:
# n_layers: 3
# units_0: 130
# units_1: 40
# activation_0: relu
# activation_1: tanh
# learning_rate: 1.0
# batch_size: 800
# units_2: 30
# activation_2: relu
# Score: 0.4062245488166809
#
# Trial 0 summary
# Hyperparameters:
# n_layers: 3
# units_0: 100
# units_1: 200
# activation_0: relu
# activation_1: tanh
# learning_rate: 1.0
# batch_size: 1400
# units_2: 10
# activation_2: relu
# Score: 0.4073092043399811

# %%
nepochs = 20

best_model = tuner.get_best_models(num_models=1)[0]
hist = best_model.fit(
    x = mydata.X_train,
    y = mydata.Y_train,
    epochs = nepochs,
    validation_split=0.2,
    class_weight = class_weight_dict
)
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d (Conv1D)             (None, 239, 10)           310
#
#  max_pooling1d (MaxPooling1  (None, 119, 10)           0
#  D)
#
#  conv1d_1 (Conv1D)           (None, 105, 10)           1510
#
#  max_pooling1d_1 (MaxPoolin  (None, 52, 10)            0
#  g1D)
#
#  flatten (Flatten)           (None, 520)               0
#
#  dense (Dense)               (None, 90)                46890
#
#  dense_1 (Dense)             (None, 150)               13650
#
#  dense_2 (Dense)             (None, 7)                 1057
#
# =================================================================
# Total params: 63417 (247.72 KB)
# Trainable params: 63417 (247.72 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# None
# WARNING:tensorflow:From c:\Users\zvig\Desktop\python_code\ClassifyHySpecMoon\.venv\Lib\site-packages\keras\src\saving\legacy\save.py:538: The name tf.train.NewCheckpointReader is deprecated. Please use tf.compat.v1.train.NewCheckpointReader instead.
#
# Epoch 1/20
# 4468/4468 [==============================] - 12s 3ms/step - loss: 0.0828 - accuracy: 0.7813 - val_loss: 0.1357 - val_accuracy: 0.7985
# Epoch 2/20
# 4468/4468 [==============================] - 12s 3ms/step - loss: 0.0757 - accuracy: 0.7991 - val_loss: 0.1135 - val_accuracy: 0.8351
# Epoch 3/20
# 4468/4468 [==============================] - 12s 3ms/step - loss: 0.0716 - accuracy: 0.8116 - val_loss: 0.1027 - val_accuracy: 0.8479
# Epoch 4/20
# 4468/4468 [==============================] - 12s 3ms/step - loss: 0.0691 - accuracy: 0.8195 - val_loss: 0.1547 - val_accuracy: 0.7863
# Epoch 5/20
# 4468/4468 [==============================] - 12s 3ms/step - loss: 0.0630 - accuracy: 0.8327 - val_loss: 0.0795 - val_accuracy: 0.8814
# Epoch 6/20
# 4468/4468 [==============================] - 12s 3ms/step - loss: 0.0602 - accuracy: 0.8413 - val_loss: 0.2303 - val_accuracy: 0.7449
# Epoch 7/20
# 4468/4468 [==============================] - 12s 3ms/step - loss: 0.0589 - accuracy: 0.8451 - val_loss: 0.0739 - val_accuracy: 0.8933
# Epoch 8/20
# 4468/4468 [==============================] - 12s 3ms/step - loss: 0.0563 - accuracy: 0.8514 - val_loss: 0.1253 - val_accuracy: 0.8300
# Epoch 9/20
# 4468/4468 [==============================] - 12s 3ms/step - loss: 0.0544 - accuracy: 0.8575 - val_loss: 0.0979 - val_accuracy: 0.8554
# Epoch 10/20
# 4468/4468 [==============================] - 12s 3ms/step - loss: 0.0533 - accuracy: 0.8606 - val_loss: 0.0775 - val_accuracy: 0.8934
# Epoch 11/20
# 4468/4468 [==============================] - 12s 3ms/step - loss: 0.0528 - accuracy: 0.8620 - val_loss: 0.1017 - val_accuracy: 0.8541
# Epoch 12/20
# 4468/4468 [==============================] - 12s 3ms/step - loss: 0.0515 - accuracy: 0.8656 - val_loss: 0.0641 - val_accuracy: 0.9072
# Epoch 13/20
# 4468/4468 [==============================] - 12s 3ms/step - loss: 0.0485 - accuracy: 0.8720 - val_loss: 0.0751 - val_accuracy: 0.8894
# Epoch 14/20
# 4468/4468 [==============================] - 12s 3ms/step - loss: 0.0499 - accuracy: 0.8696 - val_loss: 0.0841 - val_accuracy: 0.8828
# Epoch 15/20
# 4468/4468 [==============================] - 12s 3ms/step - loss: 0.0462 - accuracy: 0.8773 - val_loss: 0.0901 - val_accuracy: 0.8710
# Epoch 16/20
# 4468/4468 [==============================] - 12s 3ms/step - loss: 0.0469 - accuracy: 0.8760 - val_loss: 0.0911 - val_accuracy: 0.8685
# Epoch 17/20
# 4468/4468 [==============================] - 12s 3ms/step - loss: 0.0458 - accuracy: 0.8785 - val_loss: 0.0697 - val_accuracy: 0.9032
# Epoch 18/20
# 4468/4468 [==============================] - 12s 3ms/step - loss: 0.0448 - accuracy: 0.8814 - val_loss: 0.0787 - val_accuracy: 0.8860
# Epoch 19/20
# 4468/4468 [==============================] - 12s 3ms/step - loss: 0.0448 - accuracy: 0.8824 - val_loss: 0.0664 - val_accuracy: 0.9088
# Epoch 20/20
# 4468/4468 [==============================] - 13s 3ms/step - loss: 0.0430 - accuracy: 0.8858 - val_loss: 0.0733 - val_accuracy: 0.8907

# %%
fancyfont = {'fontname':'Times New Roman'}
font = fnt_mang.FontProperties(family='Times New Roman',style='normal',size=10)

#Loss-validation curve
best_model.summary()

# print(mydata.Y_train)
fig,ax = plt.subplots(1,1,figsize=(6,4))
ax.plot(range(0,nepochs),hist.history['loss'],c='k',label='Training Loss')
ax.plot(range(0,nepochs),hist.history['val_loss'],c='r',label='Validation Loss')
ax.legend()

ax.set_title('Model Loss History',**fancyfont,fontsize=24)
ax.set_xlabel('Number of Epochs',**fancyfont,fontsize=18)
ax.set_ylabel('Binary Cross Entropy Loss',**fancyfont,fontsize=18)
ax.set_xticks(np.arange(0,nepochs,5),labels=np.arange(0,nepochs,5),**fancyfont,fontsize=12)
# ax.set_yticks(np.arange(1.5,4.5,0.5),labels=np.arange(1.5,4.5,0.5),**fancyfont,fontsize=12)
# plt.ylim(0,0.5)

plt.savefig('G:/My Drive/Machine Learning Project/Figures/Loss_History_onehot.png',dpi=300)
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d (Conv1D)             (None, 239, 10)           310
#
#  max_pooling1d (MaxPooling1  (None, 119, 10)           0
#  D)
#
#  conv1d_1 (Conv1D)           (None, 105, 10)           1510
#
#  max_pooling1d_1 (MaxPoolin  (None, 52, 10)            0
#  g1D)
#
#  flatten (Flatten)           (None, 520)               0
#
#  dense (Dense)               (None, 90)                46890
#
#  dense_1 (Dense)             (None, 150)               13650
#
#  dense_2 (Dense)             (None, 7)                 1057
#
# =================================================================
# Total params: 63417 (247.72 KB)
# Trainable params: 63417 (247.72 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
pred_encoded = best_model.predict(
    x = mydata.X_test
)
# Out:
# 1862/1862 [==============================] - 2s 1ms/step

# %%
c = ['#310f02','#9BC53D','#BEB2C8','#225560','#F0803C','#6DB1BF','#C6E1E6']
c_map = ListedColormap(['#310f02','#9BC53D','#BEB2C8','#225560','#F0803C','#6DB1BF','#C6E1E6'])
class_names = ['Shadows','Olivine','Southern Mare','Northern Mare','Dome Center', 'Dome Slope','Background']

lab = np.argmax(mydata.Y_test,axis=1)
pred = np.argmax(pred_encoded,axis=1)


label_dist = {}
pred_dist = {}
for i in range(0,len(class_names)):
    label_dist[class_names[i]] = mydata.Y_test[lab==i].shape[0]
    pred_dist[class_names[i]] = pred[pred==i].shape[0]

print(f'Training Data: {len(mydata.Y_train)} ({len(mydata.Y_train)/mydata.num_pixels:.0%})')
print(f'Testing Data: {len(mydata.Y_test)} ({len(mydata.Y_test)/mydata.num_pixels:.0%})')
tot_label = np.array(list(label_dist.values())).sum()
tot_pred = np.array(list(pred_dist.values())).sum()
print(f'Labeled Training Data: {tot_label}')
print(f'Predicted Test Data: {tot_pred}')

print(label_dist.values())
print(pred_dist.values())

#Class Distributions
fig1,ax = plt.subplots(1,1,figsize=(5,5))
width=0.4
ax.bar(np.arange(0,len(class_names))-width/2,list(label_dist.values()),width=width,color=c,alpha=0.5)
ax.bar(np.arange(0,len(class_names))+width/2,list(pred_dist.values()),width=width,color=c)
ax.set_xticks(np.arange(0,len(class_names)))
ax.set_xticklabels(class_names,**fancyfont,fontsize=12,rotation=70)
ax.set_yticks([])

plt.savefig('G:/My Drive/Machine Learning Project/Figures/Class_distribution_conv.png',dpi=800)

#Spatial Relations

fig2,[ax1,ax2] = plt.subplots(1,2,figsize=(10,12))
ax1.imshow(mydata.labeled_data,interpolation='none',cmap=c_map,alpha=0)
ax1.scatter(mydata.xcoord_test,mydata.ycoord_test,marker='.',s=0.8,c=lab,cmap=c_map,vmin=0,vmax=6)

ax2.imshow(mydata.labeled_data,interpolation='none',cmap=c_map,alpha=0)
ax2.scatter(mydata.xcoord_test,mydata.ycoord_test,marker='.',s=0.8,c=pred,cmap=c_map,vmin=0,vmax=6)

ax1.set_title('Test Data Labels',fontdict={'size':24,'family':'Times New Roman'})
ax2.set_title('Model Predictions',fontdict={'size':24,'family':'Times New Roman'})

ax1.set_xticks([]),ax1.set_yticks([])
ax2.set_xticks([]),ax2.set_yticks([])

print(np.count_nonzero(mydata.Y_test==6))
print(np.count_nonzero(pred==6))

print(np.array(list(label_dist.values())).sum())
print(np.array(list(pred_dist.values())).sum())

plt.savefig('G:/My Drive/Machine Learning Project/Figures/Model_Performance_convolutional.png',dpi=800)
# Out:
# Training Data: 178704 (75%)
# Testing Data: 59568 (25%)
# Labeled Training Data: 59568
# Predicted Test Data: 59568
# dict_values([3060, 788, 12041, 4328, 4837, 7569, 26945])
# dict_values([3301, 1293, 11652, 5576, 5937, 9791, 22018])
# 0
# 22018
# 59568
# 59568

# %%
import sklearn.metrics

conf = sklearn.metrics.confusion_matrix(lab,pred)
plt.imshow(conf)
plt.xticks(np.arange(7),class_names,rotation=90)
plt.yticks(np.arange(7),class_names)
plt.savefig('G:/My Drive/Machine Learning Project/Figures/Confusion_Matrix_conv.png',dpi=400)

# %%
# fig,ax = plt.subplots(1,1)
# for i in np.unique(pred):
#     ax.plot(np.mean(mydata.X_test[pred==i,:],axis=0),color=c[i])

# fig = plt.figure()

# %%
from sklearn.preprocessing import MinMaxScaler

filters,biases = best_model.layers[0].get_weights()
filters = np.transpose(np.squeeze(filters))
print(filters.shape)
scaler = MinMaxScaler((0,1),copy=False)
scaler.fit_transform(filters)
plt.imshow(filters)
# Out:
# (10, 30)

# %%
import keras
filter_model = keras.Sequential()
filter_model.add(best_model.input)
filter_model.add(best_model.layers[0])

feature_maps = filter_model.predict(mydata.X_train[1,:][np.newaxis,:])
feature_maps = np.squeeze(feature_maps)
scaler.fit_transform(feature_maps)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[24], line 12
#      10 ax2.imshow(np.transpose(feature_maps),extent = [0,210,0,10], aspect = 20, interpolation='None')
#      11 ax1.plot(mydata.wvl,mydata.X_train[1,:])
# ---> 12 ax2.set_xticklabels(np.arange(0,239),mydata.wvl)
#
# File c:\Users\zvig\Desktop\python_code\ClassifyHySpecMoon\.venv\Lib\site-packages\matplotlib\axes\_base.py:73, in _axis_method_wrapper.__set_name__.<locals>.wrapper(self, *args, **kwargs)
#      72 def wrapper(self, *args, **kwargs):
# ---> 73     return get_method(self)(*args, **kwargs)
#
# File c:\Users\zvig\Desktop\python_code\ClassifyHySpecMoon\.venv\Lib\site-packages\matplotlib\_api\deprecation.py:297, in rename_parameter.<locals>.wrapper(*args, **kwargs)
#     292     warn_deprecated(
#     293         since, message=f"The {old!r} parameter of {func.__name__}() "
#     294         f"has been renamed {new!r} since Matplotlib {since}; support "
#     295         f"for the old name will be dropped %(removal)s.")
#     296     kwargs[new] = kwargs.pop(old)
# --> 297 return func(*args, **kwargs)
#
# TypeError: Axis.set_ticklabels() takes 2 positional arguments but 3 were given

# %%
fig,[ax1,ax2] = plt.subplots(2,1,height_ratios=[2,1],figsize=(6,10))
ax1.imshow(np.transpose(feature_maps),extent = [0,210,0,10], aspect = 20, interpolation='None')
ax2.plot(mydata.wvl,mydata.X_train[1,:])
ax1.set_xticks([])
ax1.set_yticks(np.arange(0,11))

ax1.set_ylabel('Filter',**fancyfont,fontsize=20)
ax2.set_xlabel('Wavelength (nm)',**fancyfont,fontsize=20)
ax2.set_ylabel('Reflectance',**fancyfont,fontsize=20)
print(feature_maps.shape)
plt.savefig('G:/My Drive/Machine Learning Project/Figures/Spectrum_Weights.png',dpi=800)
# Out:
# (239, 10)

# %%
fig,ax = plt.subplots(1,1)
ax.plot(mydata.wvl,mydata.X_train[1,:])
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[6], line 2
#       1 fig,ax = plt.subplots(1,1)
# ----> 2 ax.plot(mydata.wvl,mydata.X_train[1,:])
#
# AttributeError: 'NeuralNetData' object has no attribute 'X_train'
